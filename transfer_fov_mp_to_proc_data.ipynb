# %% [markdown]
# ### Code to copy mark points and fov pictures from raw to proc data for easier access
# TODO: add this to the end of the suite2p preprocessing pipeline (e.g. check for each dataset if it exists)

# %%
import os
import shutil

# %%
# find any folder that contains 'fov' two levels down

def find_fov_folders(root):
    """
    Find all folders that contain 'fov' in their names, two levels down from the root directory.
    Also find all markpoint files in TSeries folders
    """
    fov_full_paths = []
    markpoint_full_paths = []

    all_mice = [d for d in os.listdir(root) if os.path.isdir(os.path.join(root, d)) and d.startswith('jm')]

    for mouse in all_mice:
        print(f"Finding fov and markpoints in mouse: {mouse}")
        mouse_path = os.path.join(root, mouse)

        mouse_sessions = [d for d in os.listdir(mouse_path) if d.startswith('20') and 'zstack' not in d]

        for session in mouse_sessions:

            session_path = os.path.join(mouse_path, session)
            # check if in session path there is a fov directory

            fov_path = os.path.join(session_path, 'fov')
            if os.path.isdir(fov_path):
                print(f"Found fov directory in {session_path}")
                fov_full_paths.append(fov_path)
            else:
                print(f"No 'fov' directory found in {session_path}, skipping")
                                      
            print(f"Checking session: {session}")
            print(f"Session lower: {session.lower()}")

            tseries_folders = [dir for dir in os.listdir(session_path) if 'TSeries' in dir]
            print(f"TSeries folders found: {tseries_folders}")

            if len(tseries_folders) == 0:
                print(f"No TSeries folders found in {session_path}, skipping")
                # go to next iteration of session loop
                continue


            elif len(tseries_folders) > 1:
                raise ValueError(f"Found more than one TSeries folder in {session_path}, found: {tseries_folders}")
            
            # tseries_folders should only have one element
            tseries_path = os.path.join(session_path, tseries_folders[0])

            markpoints_fname = [fname for fname in os.listdir(tseries_path) if 'MarkPoints.xml' in fname and not fname.startswith('.')]
            print(f"Markpoints found: {markpoints_fname}")

            if len(markpoints_fname) == 1:
                markpoints_path = os.path.join(tseries_path, markpoints_fname[0])
                markpoint_full_paths.append(markpoints_path)

            elif len(markpoints_fname) == 0:
                print(f"No MarkPoints.xml found in {tseries_path}, skipping")
            
            else:
                raise ValueError(f"Found more than one MarkPoints.xml file in {tseries_path}, found: {markpoints_fname}")
            
    print(f"Found {len(fov_full_paths)} fov folders")
    print(f"Found {len(markpoint_full_paths)} markpoint files")

    return fov_full_paths, markpoint_full_paths

def copy_folders_from_list(data_raw_root, data_proc_root, folder_list):
    """
    Copy folders from data_raw_root to data_proc_root based on a list of folder paths.
    """
    
    for folder in folder_list:
        # replace the data_raw_root with data_proc_root in the folder path
        new_folder = folder.replace(data_raw_root, data_proc_root)
        # create the new folder if it doesn't exist
        shutil.copytree(folder, new_folder, dirs_exist_ok=True)
        print(f"Copied {folder} to {new_folder}")

def copy_files_from_list(data_raw_root, data_proc_root, file_list):
    """
    Copy files from data_raw_root to data_proc_root based on a list of file paths.
    """
    
    for file in file_list:
        # replace the data_raw_root with data_proc_root in the file path
        new_file = file.replace(data_raw_root, data_proc_root)

        # remove the timeseries part of the path
        new_file = os.path.join(new_file.split("/T")[0], 'T' + new_file.split("/T")[1]+'.xml')

        # create the directory if it doesn't exist
        os.makedirs(os.path.dirname(new_file), exist_ok=True)
        shutil.copy(file, new_file)
        print(f"Copied {file} to {new_file}")

# %%
data_raw_root = 'data_raw/jm'
data_proc_root = 'data_proc/jm'

# %%
fov_full_paths, markpoint_full_paths = find_fov_folders(data_raw_root)
# Out:
# Finding fov and markpoints in mouse: jm046
# No 'fov' directory found in data_raw/jm/jm046/2024-09-09_b, skipping
# Checking session: 2024-09-09_b
# Session lower: 2024-09-09_b
# TSeries folders found: ['TSeries-10032023-1822-008']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm046/2024-09-09_b/TSeries-10032023-1822-008, skipping
# No 'fov' directory found in data_raw/jm/jm046/2024-09-03_a, skipping
# Checking session: 2024-09-03_a
# Session lower: 2024-09-03_a
# TSeries folders found: ['TSeries-10032023-1822-004']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm046/2024-09-03_a/TSeries-10032023-1822-004, skipping
# No 'fov' directory found in data_raw/jm/jm046/2024-09-09_a, skipping
# Checking session: 2024-09-09_a
# Session lower: 2024-09-09_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm046/2024-09-09_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm046/2024-09-05_a, skipping
# Checking session: 2024-09-05_a
# Session lower: 2024-09-05_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm046/2024-09-05_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm046/2024-09-06_a, skipping
# Checking session: 2024-09-06_a
# Session lower: 2024-09-06_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm046/2024-09-06_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm046/2024-09-05_b, skipping
# Checking session: 2024-09-05_b
# Session lower: 2024-09-05_b
# TSeries folders found: ['TSeries-10032023-1822-004']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm046/2024-09-05_b/TSeries-10032023-1822-004, skipping
# No 'fov' directory found in data_raw/jm/jm046/2024-09-08_a, skipping
# Checking session: 2024-09-08_a
# Session lower: 2024-09-08_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm046/2024-09-08_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm046/2024-09-02_a, skipping
# Checking session: 2024-09-02_a
# Session lower: 2024-09-02_a
# TSeries folders found: ['TSeries-10032023-1822-004']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm046/2024-09-02_a/TSeries-10032023-1822-004, skipping
# No 'fov' directory found in data_raw/jm/jm046/2024-09-07_a, skipping
# Checking session: 2024-09-07_a
# Session lower: 2024-09-07_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm046/2024-09-07_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm046/2024-09-04_a, skipping
# Checking session: 2024-09-04_a
# Session lower: 2024-09-04_a
# TSeries folders found: ['TSeries-10032023-1822-004']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm046/2024-09-04_a/TSeries-10032023-1822-004, skipping
# Finding fov and markpoints in mouse: jm036
# No 'fov' directory found in data_raw/jm/jm036/2024-04-25_a, skipping
# Checking session: 2024-04-25_a
# Session lower: 2024-04-25_a
# TSeries folders found: ['TSeries-10032023-1822-003']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm036/2024-04-25_a/TSeries-10032023-1822-003, skipping
# No 'fov' directory found in data_raw/jm/jm036/2024-04-23_a, skipping
# Checking session: 2024-04-23_a
# Session lower: 2024-04-23_a
# TSeries folders found: ['TSeries-10032023-1822-003']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm036/2024-04-23_a/TSeries-10032023-1822-003, skipping
# No 'fov' directory found in data_raw/jm/jm036/2024-04-24_a, skipping
# Checking session: 2024-04-24_a
# Session lower: 2024-04-24_a
# TSeries folders found: ['TSeries-10032023-1822-003']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm036/2024-04-24_a/TSeries-10032023-1822-003, skipping
# Finding fov and markpoints in mouse: jm047
# No 'fov' directory found in data_raw/jm/jm047/2024-09-02_a, skipping
# Checking session: 2024-09-02_a
# Session lower: 2024-09-02_a
# TSeries folders found: ['TSeries-10032023-1822-004']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm047/2024-09-02_a/TSeries-10032023-1822-004, skipping
# Finding fov and markpoints in mouse: jm052
# Found fov directory in data_raw/jm/jm052/2025-05-22_a
# Checking session: 2025-05-22_a
# Session lower: 2025-05-22_a
# TSeries folders found: ['TSeries-10032023-1822-021']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm052/2025-05-22_a/TSeries-10032023-1822-021, skipping
# Found fov directory in data_raw/jm/jm052/2025-05-24_b
# Checking session: 2025-05-24_b
# Session lower: 2025-05-24_b
# TSeries folders found: ['TSeries-10032023-1822-021']
# Markpoints found: ['TSeries-10032023-1822-021_Cycle00001_MarkPoints.xml']
# Found fov directory in data_raw/jm/jm052/2025-05-23_b
# Checking session: 2025-05-23_b
# Session lower: 2025-05-23_b
# TSeries folders found: ['TSeries-10032023-1822-021']
# Markpoints found: ['TSeries-10032023-1822-021_Cycle00001_MarkPoints.xml']
# Finding fov and markpoints in mouse: jm048
# No 'fov' directory found in data_raw/jm/jm048/2025-05-08_c, skipping
# Checking session: 2025-05-08_c
# Session lower: 2025-05-08_c
# TSeries folders found: ['TSeries-10032023-1822-009']
# Markpoints found: ['TSeries-10032023-1822-009_Cycle00001_MarkPoints.xml']
# Found fov directory in data_raw/jm/j
Cycle00001_MarkPoints.xml']
# Found fov directory in data_raw/jm/jm050/2025-05-23_b
# Checking session: 2025-05-23_b
# Session lower: 2025-05-23_b
# TSeries folders found: ['TSeries-10032023-1822-019']
# Markpoints found: ['TSeries-10032023-1822-019_Cycle00001_MarkPoints.xml']
# Finding fov and markpoints in mouse: jm041
# No 'fov' directory found in data_raw/jm/jm041/2024-05-01_a, skipping
# Checking session: 2024-05-01_a
# Session lower: 2024-05-01_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm041/2024-05-01_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm041/2024-05-02_a, skipping
# Checking session: 2024-05-02_a
# Session lower: 2024-05-02_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm041/2024-05-02_a/TSeries-10032023-1822-005, skipping
# Finding fov and markpoints in mouse: jm042
# No 'fov' directory found in data_raw/jm/jm042/2024-08-27_a, skipping
# Checking session: 2024-08-27_a
# Session lower: 2024-08-27_a
# TSeries folders found: ['TSeries-10032023-1822-004']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm042/2024-08-27_a/TSeries-10032023-1822-004, skipping
# No 'fov' directory found in data_raw/jm/jm042/2024-08-29_a, skipping
# Checking session: 2024-08-29_a
# Session lower: 2024-08-29_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm042/2024-08-29_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm042/2024-08-28_a, skipping
# Checking session: 2024-08-28_a
# Session lower: 2024-08-28_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm042/2024-08-28_a/TSeries-10032023-1822-005, skipping
# Finding fov and markpoints in mouse: jm037
# No 'fov' directory found in data_raw/jm/jm037/2024-04-28_b, skipping
# Checking session: 2024-04-28_b
# Session lower: 2024-04-28_b
# TSeries folders found: ['TSeries-10032023-1822-006']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-28_b/TSeries-10032023-1822-006, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-24_b, skipping
# Checking session: 2024-04-24_b
# Session lower: 2024-04-24_b
# TSeries folders found: ['TSeries-10032023-1822-006']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-24_b/TSeries-10032023-1822-006, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-25_a, skipping
# Checking session: 2024-04-25_a
# Session lower: 2024-04-25_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-25_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-27_b, skipping
# Checking session: 2024-04-27_b
# Session lower: 2024-04-27_b
# TSeries folders found: ['TSeries-10032023-1822-006']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-27_b/TSeries-10032023-1822-006, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-23_a, skipping
# Checking session: 2024-04-23_a
# Session lower: 2024-04-23_a
# TSeries folders found: ['TSeries-10032023-1822-003']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-23_a/TSeries-10032023-1822-003, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-26_b, skipping
# Checking session: 2024-04-26_b
# Session lower: 2024-04-26_b
# TSeries folders found: ['TSeries-10032023-1822-006']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-26_b/TSeries-10032023-1822-006, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-25_b, skipping
# Checking session: 2024-04-25_b
# Session lower: 2024-04-25_b
# TSeries folders found: ['TSeries-10032023-1822-006']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-25_b/TSeries-10032023-1822-006, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-28_a, skipping
# Checking session: 2024-04-28_a
# Session lower: 2024-04-28_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-28_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-24_a, skipping
# Checking session: 2024-04-24_a
# Session lower: 2024-04-24_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-24_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-23_b, skipping
# Checking session: 2024-04-23_b
# Session lower: 2024-04-23_b
# TSeries folders found: ['TSeries-10032023-1822-004']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-23_b/TSeries-10032023-1822-004, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-30_b, skipping
# Checking session: 2024-04-30_b
# Session lower: 2024-04-30_b
# TSeries folders found: ['TSeries-10032023-1822-006']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-30_b/TSeries-10032023-1822-006, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-30_a, skipping
# Checking session: 2024-04-30_a
# Session lower: 2024-04-30_a
# TSeries folders found: ['TSeries-10032023-1822-006']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-30_a/TSeries-10032023-1822-006, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-29_b, skipping
# Checking session: 2024-04-29_b
# Session lower: 2024-04-29_b
# TSeries folders found: ['TSeries-10032023-1822-007']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-29_b/TSeries-10032023-1822-007, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-29_a, skipping
# Checking session: 2024-04-29_a
# Session lower: 2024-04-29_a
# TSeries folders found: ['TSeries-10032023-1822-006']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-29_a/TSeries-10032023-1822-006, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-26_a, skipping
# Checking session: 2024-04-26_a
# Session lower: 2024-04-26_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-26_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm037/2024-04-27_a, skipping
# Checking session: 2024-04-27_a
# Session lower: 2024-04-27_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm037/2024-04-27_a/TSeries-10032023-1822-005, skipping
# Finding fov and markpoints in mouse: jm049
# Found fov directory in data_raw/jm/jm049/2025-05-23_c
# Checking session: 2025-05-23_c
# Session lower: 2025-05-23_c
# TSeries folders found: ['TSeries-10032023-1822-016']
# Markpoints found: ['TSeries-10032023-1822-016_Cycle00001_MarkPoints.xml']
# Found fov directory in data_raw/jm/jm049/2025-05-21_a
# Checking session: 2025-05-21_a
# Session lower: 2025-05-21_a
# TSeries folders found: ['TSeries-10032023-1822-009']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm049/2025-05-21_a/TSeries-10032023-1822-009, skipping
# Found fov directory in data_raw/jm/jm049/2025-05-22_a
# Checking session: 2025-05-22_a
# Session lower: 2025-05-22_a
# TSeries folders found: ['TSeries-10032023-1822-016']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm049/2025-05-22_a/TSeries-10032023-1822-016, skipping
# Found fov directory in data_raw/jm/jm049/2025-05-23_d
# Checking session: 2025-05-23_d
# Session lower: 2025-05-23_d
# TSeries folders found: ['TSeries-10032023-1822-017']
# Markpoints found: ['TSeries-10032023-1822-017_Cycle00001_MarkPoints.xml']
# Found fov directory in data_raw/jm/jm049/2025-05-24_b
# Checking session: 2025-05-24_b
# Session lower: 2025-05-24_b
# TSeries folders found: ['TSeries-10032023-1822-018']
# Markpoints found: ['TSeries-10032023-1822-018_Cycle00001_MarkPoints.xml']
# Found fov directory in data_raw/jm/jm049/2025-05-25_b
# Checking session: 2025-05-25_b
# Session lower: 2025-05-25_b
# TSeries folders found: ['TSeries-10032023-1822-019']
# Markpoints found: ['TSeries-10032023-1822-019_Cycle00001_MarkPoints.xml']
# Found fov directory in data_raw/jm/jm049/2025-05-23_b
# Checking session: 2025-05-23_b
# Session lower: 2025-05-23_b
# TSeries folders found: ['TSeries-10032023-1822-018']
# Markpoints found: ['TSeries-10032023-1822-018_Cycle00001_MarkPoints.xml']
# Found fov directory in data_raw/jm/jm049/2025-05-25_c
# Checking session: 2025-05-25_c
# Session lower: 2025-05-25_c
# TSeries folders found: ['TSeries-10032023-1822-018']
# Markpoints found: ['TSeries-10032023-1822-018_Cycle00001_MarkPoints.xml']
# No 'fov' directory found in data_raw/jm/jm049/2025-05-21_b, skipping
# Checking session: 2025-05-21_b
# Session lower: 2025-05-21_b
# TSeries folders found: ['TSeries-10032023-1822-016']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm049/2025-05-21_b/TSeries-10032023-1822-016, skipping
# Finding fov and markpoints in mouse: jm043
# No 'fov' directory found in data_raw/jm/jm043/2024-08-27_a, skipping
# Checking session: 2024-08-27_a
# Session lower: 2024-08-27_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm043/2024-08-27_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm043/2024-08-30_a, skipping
# Checking session: 2024-08-30_a
# Session lower: 2024-08-30_a
# TSeries folders found: ['TSeries-10032023-1822-006']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm043/2024-08-30_a/TSeries-10032023-1822-006, skipping
# No 'fov' directory found in data_raw/jm/jm043/2024-08-29_a, skipping
# Checking session: 2024-08-29_a
# Session lower: 2024-08-29_a
# TSeries folders found: ['TSeries-10032023-1822-006']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm043/2024-08-29_a/TSeries-10032023-1822-006, skipping
# No 'fov' directory found in data_raw/jm/jm043/2024-08-28_a, skipping
# Checking session: 2024-08-28_a
# Session lower: 2024-08-28_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm043/2024-08-28_a/TSeries-10032023-1822-005, skipping
# Finding fov and markpoints in mouse: jm045
# No 'fov' directory found in data_raw/jm/jm045/2024-08-27_a, skipping
# Checking session: 2024-08-27_a
# Session lower: 2024-08-27_a
# TSeries folders found: ['TSeries-10032023-1822-004']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm045/2024-08-27_a/TSeries-10032023-1822-004, skipping
# No 'fov' directory found in data_raw/jm/jm045/2024-08-30_a, skipping
# Checking session: 2024-08-30_a
# Session lower: 2024-08-30_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm045/2024-08-30_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm045/2024-08-29_a, skipping
# Checking session: 2024-08-29_a
# Session lower: 2024-08-29_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm045/2024-08-29_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm045/2024-08-28_a, skipping
# Checking session: 2024-08-28_a
# Session lower: 2024-08-28_a
# TSeries folders found: ['TSeries-10032023-1822-004']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm045/2024-08-28_a/TSeries-10032023-1822-004, skipping
# No 'fov' directory found in data_raw/jm/jm045/2024-08-31_a, skipping
# Checking session: 2024-08-31_a
# Session lower: 2024-08-31_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm045/2024-08-31_a/TSeries-10032023-1822-005, skipping
# Finding fov and markpoints in mouse: jm053
# Found fov directory in data_raw/jm/jm053/2025-04-30_b
# Checking session: 2025-04-30_b
# Session lower: 2025-04-30_b
# TSeries folders found: ['TSeries-10032023-1822-003']
# Markpoints found: ['TSeries-10032023-1822-003_Cycle00001_MarkPoints.xml']
# Finding fov and markpoints in mouse: jm051
# Found fov directory in data_raw/jm/jm051/2025-05-23_c
# Checking session: 2025-05-23_c
# Session lower: 2025-05-23_c
# TSeries folders found: ['TSeries-10032023-1822-014']
# Markpoints found: ['TSeries-10032023-1822-014_Cycle00001_MarkPoints.xml']
# Found fov directory in data_raw/jm/jm051/2025-05-26_b
# Checking session: 2025-05-26_b
# Session lower: 2025-05-26_b
# TSeries folders found: ['TSeries-10032023-1822-014']
# Markpoints found: ['TSeries-10032023-1822-014_Cycle00001_MarkPoints.xml']
# No 'fov' directory found in data_raw/jm/jm051/2025-05-21_a, skipping
# Checking session: 2025-05-21_a
# Session lower: 2025-05-21_a
# TSeries folders found: ['TSeries-10032023-1822-013']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm051/2025-05-21_a/TSeries-10032023-1822-013, skipping
# Found fov directory in data_raw/jm/jm051/2025-05-22_a
# Checking session: 2025-05-22_a
# Session lower: 2025-05-22_a
# TSeries folders found: ['TSeries-10032023-1822-014']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm051/2025-05-22_a/TSeries-10032023-1822-014, skipping
# Found fov directory in data_raw/jm/jm051/2025-05-24_b
# Checking session: 2025-05-24_b
# Session lower: 2025-05-24_b
# TSeries folders found: ['TSeries-10032023-1822-014']
# Markpoints found: ['TSeries-10032023-1822-014_Cycle00001_MarkPoints.xml']
# Found fov directory in data_raw/jm/jm051/2025-05-25_b
# Checking session: 2025-05-25_b
# Session lower: 2025-05-25_b
# TSeries folders found: ['TSeries-10032023-1822-014']
# Markpoints found: ['TSeries-10032023-1822-014_Cycle00001_MarkPoints.xml']
# Found fov directory in data_raw/jm/jm051/2025-05-23_b
# Checking session: 2025-05-23_b
# Session lower: 2025-05-23_b
# TSeries folders found: ['TSeries-10032023-1822-014']
# Markpoints found: ['TSeries-10032023-1822-014_Cycle00001_MarkPoints.xml']
# Finding fov and markpoints in mouse: jm040
# No 'fov' directory found in data_raw/jm/jm040/2024-05-03_a, skipping
# Checking session: 2024-05-03_a
# Session lower: 2024-05-03_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm040/2024-05-03_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm040/2024-05-07_a, skipping
# Checking session: 2024-05-07_a
# Session lower: 2024-05-07_a
# TSeries folders found: []
# No TSeries folders found in data_raw/jm/jm040/2024-05-07_a, skipping
# No 'fov' directory found in data_raw/jm/jm040/2024-05-01_a, skipping
# Checking session: 2024-05-01_a
# Session lower: 2024-05-01_a
# TSeries folders found: ['TSeries-10032023-1822-007']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm040/2024-05-01_a/TSeries-10032023-1822-007, skipping
# No 'fov' directory found in data_raw/jm/jm040/2024-05-02_a, skipping
# Checking session: 2024-05-02_a
# Session lower: 2024-05-02_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm040/2024-05-02_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm040/2024-05-04_a, skipping
# Checking session: 2024-05-04_a
# Session lower: 2024-05-04_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm040/2024-05-04_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm040/2024-05-06_a, skipping
# Checking session: 2024-05-06_a
# Session lower: 2024-05-06_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm040/2024-05-06_a/TSeries-10032023-1822-005, skipping
# No 'fov' directory found in data_raw/jm/jm040/2024-05-05_a, skipping
# Checking session: 2024-05-05_a
# Session lower: 2024-05-05_a
# TSeries folders found: ['TSeries-10032023-1822-005']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm040/2024-05-05_a/TSeries-10032023-1822-005, skipping
# Finding fov and markpoints in mouse: jm044
# No 'fov' directory found in data_raw/jm/jm044/2024-08-27_a, skipping
# Checking session: 2024-08-27_a
# Session lower: 2024-08-27_a
# TSeries folders found: ['TSeries-10032023-1822-004']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm044/2024-08-27_a/TSeries-10032023-1822-004, skipping
# No 'fov' directory found in data_raw/jm/jm044/2024-08-30_a, skipping
# Checking session: 2024-08-30_a
# Session lower: 2024-08-30_a
# TSeries folders found: ['TSeries-10032023-1822-004']
# Markpoints found: []
# No MarkPoints.xml found in data_raw/jm/jm044/2024-08-30_a/TSeries-10032023-1822-004, skipping
# No 'fov' directory found in data_raw/jm/j