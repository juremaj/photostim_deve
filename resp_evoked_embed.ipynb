# %% [markdown]
# # Embedding of evoked responses and TCA (fixed lag)
# Inspired by 'ripples' paper where time are used as features to investigate diversity of responses across age and cells

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import os

session_paths = [
    'data_proc_ssd/jm/jm064/2025-11-13_s',
    'data_proc_ssd/jm/jm064/2025-11-14_s',
    'data_proc_ssd/jm/jm064/2025-11-15_s',
    'data_proc_ssd/jm/jm064/2025-11-16_s',
    'data_proc_ssd/jm/jm064/2025-11-17_s',
    'data_proc_ssd/jm/jm064/2025-11-18_s'
]

t2p_indices_path = 'data_proc_ssd/jm/jm064/track2p/plane0_suite2p_indices.npy'

st_analysis = True
animate_3d_rotation = True
FIG_DPI     = 400
n_neighbours_umap = 50

# TODO: maybe also consider median subtraction instead of mean!
subtract_baseline = True  # whether to subtract the pre-stimulus baseline from each neuron's averaged response

lag_param = 13   # fixed lag (frames) applied to all feature templates
sin_phase_shift = 7 * np.pi / 12 # phase shift for the osc feature (to make it symmetric - orthogonal to asymm)

all_resp_evoked = []
for session_path in session_paths:
    all_resp_evoked.append(np.load(os.path.join(session_path, 'resp_evoked', 'resp_evoked.npy'), allow_pickle=True).item())

n_features = all_resp_evoked[0]['resp_mean'].shape[1]
n_days = len(all_resp_evoked)
n_neurons = all_resp_evoked[0]['resp_mean'].shape[0]

# %%
n_trials = 60
all_resp_mean = np.zeros((n_days, n_neurons, n_features))
all_resp = np.zeros((n_days, n_trials, n_neurons, n_features))


for i, resp_evoked in enumerate(all_resp_evoked):
    all_resp_mean[i] = resp_evoked['resp_mean']
    print(resp_evoked['resp'].shape)
    all_resp[i] = resp_evoked['resp']

if subtract_baseline:
    pre_stim_frames = np.arange(0, 15)  # frames before stimulus onset
    baseline = np.mean(all_resp_mean[:, :, pre_stim_frames], axis=2, keepdims=True)
    all_resp_mean -= baseline

    # now subtract the same baseline from the single-trial
    all_resp -= baseline[:, np.newaxis, :, :]

    

# now plot some example neurons across days
neuron_idxs = np.int64(np.linspace(0, n_neurons-1, 5))

for neuron_idx in neuron_idxs:
    fig, axs = plt.subplots(1, n_days, figsize=(15, 1), sharey=True)
    for day in range(n_days):
        axs[day].plot(all_resp_mean[day, neuron_idx])
        axs[day].set_title(f'Day {day+1}')
    plt.suptitle(f'Neuron {neuron_idx}')
    plt.show()

# %%
print(all_resp.shape)
# now flatten the data for dimensionality reduction (neurons*trials*days x features)
all_resp_flat = all_resp.reshape(-1, n_features)
print(all_resp_flat.shape)
# now label rows by day

# %%
# now import and run umap
import umap
from sklearn.decomposition import PCA

# %%
def zscore_rows(X):
    return (X - X.mean(axis=1, keepdims=True)) / X.std(axis=1, keepdims=True)

# %%
# flatten all_resp_mean along the days dimension and add labels (to color code the points by day)
data_mn = all_resp_mean.reshape(-1, n_features)
data_st = all_resp_flat
# # Compute the PSD: Instead of feeding raw time series into UMAP, feed it the Power Spectral Density (PSD) or the magnitude of the Fast Fourier Transform (FFT).
# data_psd = np.abs(np.fft.fft(data, axis=1))

# data = zscore_rows(data_psd)

labels_mn = np.repeat(np.arange(n_days), n_neurons)
labels_st = np.repeat(np.arange(n_days), n_neurons*n_trials)

# %%
# now fit umap and visualise
reducer_mn = umap.UMAP(
    random_state=42, n_neighbors=n_neighbours_umap
)
emb_umap_mn = reducer_mn.fit_transform(data_mn)

# %%
if st_analysis:
    reducer_st = umap.UMAP(
        random_state=42, n_neighbors=n_neighbours_umap
    )

    emb_umap_st = reducer_st.fit_transform(data_st)
else:
    print('ST analysis is disabled, skipping ST UMAP embedding.')

# %%
nrn_idx = 306
nrn_idx_days = [nrn_idx + i*n_neurons for i in range(n_days)]

# %%
plt.figure(figsize=(14, 10), dpi=300)
plt.scatter(emb_umap_mn[:, 0], emb_umap_mn[:, 1], s=30)
plt.axis('off')
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=18)
cbar.set_label('Postnatal day', fontsize=24)

# %%
plt.figure(figsize=(14, 10), dpi=300)
plt.scatter(emb_umap_mn[:, 0], emb_umap_mn[:, 1], c=labels_mn+8, s=30, cmap='viridis')
plt.axis('off')
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=18)
cbar.set_label('Postnatal day', fontsize=24)

# %%
if st_analysis:
    plt.figure(figsize=(14, 10), dpi=300)
    plt.scatter(emb_umap_st[:, 0], emb_umap_st[:, 1], c=labels_st+8, s=0.1, cmap='viridis', alpha=0.5)
    plt.axis('off')
    cbar = plt.colorbar()
    cbar.ax.tick_params(labelsize=18)
    cbar.set_label('Postnatal day', fontsize=24)
else:
    print('ST analysis is disabled, skipping ST UMAP plot.')

# %%
# now get the centroid of the points corresponding to all of the trials of a given neuron on a given day

if st_analysis:
    nrn_idx = 33
    all_centroid = np.zeros((n_days, 2))
    for d in range(n_days):
        # get indices of the points corresponding to the trials of neuron nrn_idx on day d
        trial_indices = np.where(labels_st == d)[0]
        neuron_trial_indices = trial_indices[trial_indices % n_neurons == nrn_idx]
        neuron_trial_points = emb_umap_st[neuron_trial_indices]
        all_centroid[d] = neuron_trial_points.mean(axis=0)

        print(f'Centroid for neuron {nrn_idx} on day {d+1}: {all_centroid[d]}')
else:
    print('ST analysis is disabled, skipping centroid calculation.')

# %%
ex_nrn_idxs = [33, 94, 284, 60, 47, 127, 282, 329]

# %%
if st_analysis:
    for nrn_idx in ex_nrn_idxs:
        
        all_centroid = np.zeros((n_days, 2))
        for d in range(n_days):
            # get indices of the points corresponding to the trials of neuron nrn_idx on day d
            trial_indices = np.where(labels_st == d)[0]
            neuron_trial_indices = trial_indices[trial_indices % n_neurons == nrn_idx]
            neuron_trial_points = emb_umap_st[neuron_trial_indices]
            all_centroid[d] = neuron_trial_points.mean(axis=0)

            print(f'Centroid for neuron {nrn_idx} on day {d+1}: {all_centroid[d]}')

        plt.figure(figsize=(14, 10), dpi=300)
        plt.scatter(emb_umap_st[:, 0], emb_umap_st[:, 1], c=labels_st+8, s=0.1, cmap='viridis', alpha=0.5)
        # now plot the centroids
        plt.scatter(all_centroid[:, 0], all_centroid[:, 1], c=np.arange(n_days)+8, s=50, cmap='viridis', label=f'Neuron {nrn_idx} centroids', zorder=3)
        plt.plot(all_centroid[:, 0], all_centroid[:, 1], c='grey', linewidth=3, zorder=2, label='Trajectory')
        plt.legend()
        plt.axis('off')
        cbar = plt.colorbar()
        cbar.ax.tick_params(labelsize=18)
        cbar.set_label('Postnatal day', fontsize=24)
        plt.show()
else:
    print('ST analysis is disabled, skipping centroid plotting.')

# %%
for nrn_idx in ex_nrn_idxs:
    nrn_idx_days = [nrn_idx + i*n_neurons for i in range(n_days)]
    
    fig, axs = plt.subplot_mosaic(mosaic='AAAAAA\nAAAAAA\nAAAAAA\nAAAAAA\nAAAAAA\nAAAAAA\nBCDEFG', figsize=(10, 10), dpi=300)
    # make the BCDEFG share y axis
    for ax in ['B', 'C', 'D', 'E', 'F', 'G']:
        axs[ax].sharey(axs['B'])
    axs['A'].scatter(emb_umap_mn[:, 0], emb_umap_mn[:, 1], c=labels_mn, s=5, cmap='viridis',alpha=0.7, zorder=0)
    axs['A'].scatter(emb_umap_mn[nrn_idx_days, 0], emb_umap_mn[nrn_idx_days, 1], c=np.arange(n_days), s=200, cmap='viridis')
    axs['A'].plot(emb_umap_mn[nrn_idx_days, 0], emb_umap_mn[nrn_idx_days, 1], c='gray', alpha=0.5, label=f'Trajectory of neuron {nrn_idx}', linewidth=5)
    axs['A'].set_title('UMAP embedding of evoked responses')
    axs['A'].set_xlabel('UMAP 1')
    axs['A'].set_ylabel('UMAP 2')
    # remove axis
    axs['A'].axis('off')
    # add legend to top left corner of the plot
    axs['A'].legend(loc='upper left', frameon=False)
    # add colormap labelled with the day numbers
    other_days = 'BCDEFG'
    for day in range(n_days):
        # get color based on 'viridis' colormap and the day index
        color = plt.cm.viridis(day/ (n_days-1))
        axs[other_days[day]].plot(all_resp_mean[day, nrn_idx], color=color, linewidth=3.5)
        axs[other_days[day]].axhline(0, color='k', lw=2, alpha=0.2, zorder=0)
        axs[other_days[day]].set_xticks([])
        axs[other_days[day]].set_yticks([]) 
        axs[other_days[day]].set_axis_off()
        # add f'P{8+day}' to top left corner of the subplot
        axs[other_days[day]].text(0.05, 0.95, f'P{8+day}', transform=axs[other_days[day]].transAxes, fontsize=16, verticalalignment='top', color=color)

# %%
import tensortools as tt

data = all_resp_mean # ... specify a numpy array holding the tensor you wish to fit
# data = all_resp.reshape(n_days, n_trials*n_neurons, n_features) # ... specify a numpy array holding the tensor you wish to fit

# Fit an ensemble of models, 4 random replicates / optimization runs per model rank
ensemble = tt.Ensemble(fit_method="ncp_hals")
ensemble.fit(data, ranks=range(1, 10), replicates=5)

fig, axes = plt.subplots(1, 2)
tt.plot_objective(ensemble, ax=axes[0])   # plot reconstruction error as a function of num components.
tt.plot_similarity(ensemble, ax=axes[1])  # plot model similarity as a function of num components.
fig.tight_layout()

# Plot the low-d factors for an example model, e.g. rank-2, first optimization run / replicate.
num_components = 5
replicate = 0
# color lines in 'C1' 
tt.plot_factors(ensemble.factors(num_components)[replicate], line_kw=[{'color': 'C2'}, {'color': 'C0'}, {'color': 'C3'}])  # plot the low-d factors

plt.show()

# %%
day_components = np.zeros((num_components, n_days))
nrn_components = np.zeros((num_components, n_neurons))
feature_components = np.zeros((num_components, n_features))

for i in range(num_components):
    day_components[i] = ensemble.factors(num_components)[replicate][0][:, i]
    nrn_components[i] = ensemble.factors(num_components)[replicate][1][:, i]
    feature_components[i] = ensemble.factors(num_components)[replicate][2][:, i]

# %%
fig, axs = plt.subplots(num_components, 1, figsize=(2, 5))
for i in range(num_components):
    axs[i].hist(nrn_components[i,:], bins=26)
    axs[i].axis('off')
plt.show()

# %%
# now scatter the umap embedding color coded by the TCA component embedding
for i in range(num_components):
    # outer product of neuron and day componentsa
    c = np.outer(day_components[i], nrn_components[i, :]).flatten()
    # now do the log to get a logarithmic color scale (since the values are mostly close to zero, with some large outliers)
    c = np.log(np.abs(c) + 1e-5)  # add a small value to avoid log(0)
    
    fig, axs = plt.subplot_mosaic(mosaic='AAA\nAAA\nAAA\nAAA\nAAA\nAAA\nBCD', figsize=(10, 8), dpi=300)
    axs['A'].scatter(
        emb_umap_mn[:, 0],
        emb_umap_mn[:, 1],
        c=c,
        s=5,
        cmap='viridis'
    )
    axs['A'].axis('off')
    cbar = fig.colorbar(axs['A'].collections[0], ax=axs['A'], ticks=[], shrink=0.8)
    cbar.set_label(fr'$TC{i+1}_{{\mathrm{{day}}}}\otimes TC{i+1}_{{\mathrm{{neuron}}}}$ (log scale)', fontsize=12)
    axs['A'].set_title(f'UMAP embedding colored by TCA component {i+1}')
    axs['B'].plot(day_components[i], color='C2')
    axs['B'].set_title(f'Day component {i+1}')
    axs['B'].set_axis_off()
    axs['C'].plot(nrn_components[i, :], color='C0')
    axs['C'].set_title(f'Neuron component {i+1}')
    axs['C'].set_axis_off()
    axs['D'].plot(feature_components[i, :], color='C3')
    axs['D'].set_title(f'Feature component {i+1}')
    axs['D'].set_axis_off()

    plt.show()

# %%
# now do a raster plot just showing the dynamics of each day side by side

# %% [markdown]
# ## 2 · Manual-feature correlations

# %%
# ─────────────────────────────────────────────────────────────────
# 2 · Manual feature definitions & correlation with neural responses
# ─────────────────────────────────────────────────────────────────

STIM_START   = 15
STIM_FRAMES  = 60
STIM_END     = STIM_START + STIM_FRAMES   # = 75
AGE_OFFSET   = 8


# ── 2a · Feature templates ───────────────────────────────────────

def make_manual_features(n_features, stim_start=STIM_START, stim_frames=STIM_FRAMES, phase_shift=np.pi/2):
    """Return a dict of named unit-norm, zero-mean feature templates.

    All features are non-zero only inside the stimulus window and are
    mean-subtracted so that cells with a flat sustained response do not
    project onto the asymming filters.

    Features
    --------
    step  : square pulse (1 during stim, 0 elsewhere) — NOT mean-subtracted
              because it is intended to capture plateau responses
    osc : 5 full cosine cycles during stimulus (phase +π/2, symmetric
              about the stimulus midpoint — equal half-lobes at both edges)
    asymm    : linear asymm 0→1 with mean removed  → captures asymm-up only
    phase_shift : float, optional  phase shift for the osc feature (default π/2 for cosine-like)
    """
    stim_end = stim_start + stim_frames
    t_stim   = np.arange(stim_frames, dtype=float)

    def _embed(kernel):
        """Place a stim-length kernel at the correct position in the full vector."""
        f = np.zeros(n_features)
        f[stim_start:stim_end] = kernel
        return f

    step  = _embed(np.ones(stim_frames))
    step /= np.max(np.abs(step))  # scale to ±1

    # 5 cosine cycles (phase +π/2 vs sin): peak at t=0, symmetric half-lobes at both edges
    osc = _embed(np.sin(2 * np.pi * 5 * t_stim / stim_frames + phase_shift))
    osc /= np.max(np.abs(osc))  # scale to ±1

    # asymm up: subtract mean so a flat plateau gives r ≈ 0
    asymm_raw = np.linspace(0, 1, stim_frames)
    asymm     = _embed(asymm_raw - asymm_raw.mean())
    asymm /= np.max(np.abs(asymm))  # scale to ±1

    raw = {'step': step, 'osc': osc, 'asymm': asymm}
    return {k: v / (np.linalg.norm(v) + 1e-12) for k, v in raw.items()}


features = make_manual_features(n_features, phase_shift=sin_phase_shift)  # cosine-like


# ── 2b · Plot feature templates ──────────────────────────────────

fig, axs = plt.subplots(1, len(features), figsize=(3 * len(features), 2.5), dpi=FIG_DPI)

for ax, (name, f) in zip(axs, features.items()):
    f /= np.max(np.abs(f))  # ensure ±1 range for plotting
    ax.plot(f, color='k', lw=2)
    ax.axvspan(STIM_START, STIM_END, color='lightgray', alpha=0.3)
    ax.axhline(0, color='k', lw=0.5, ls='--')
    ax.set_title(name, fontsize=10)
    ax.set_xlabel('Time (frames)', fontsize=8)
    ax.set_ylabel('Amplitude', fontsize=8)
    ax.tick_params(labelsize=7)
    ax.spines[['top', 'right']].set_visible(False)
    ax.set_ylim(-1.1, 1.1)

fig.suptitle('Manual feature templates', fontsize=12)
plt.tight_layout()
plt.show()


def compute_fixed_lag_correlations(all_resp_mean, features, lag_param,
                                    stim_start=STIM_START, stim_frames=STIM_FRAMES):
    """Feature correlations with every template shifted by a fixed lag.

    Parameters
    ----------
    all_resp_mean : ndarray (n_days, n_neurons, n_features)
    features      : dict {name: 1-D array length n_features}
    lag_param     : int  fixed lag in frames (template shifted right by this amount)

    Returns
    -------
    xcorr_dict  : dict {name + ' (xcorr)': ndarray (n_days * n_neurons,)}
    lag_dict    : dict {name + ' lag': ndarray (n_days * n_neurons,)}  all = lag_param
    age_labels  : 1-D int array
    """
    n_days, n_neurons, nf = all_resp_mean.shape
    N = n_days * n_neurons

    X  = all_resp_mean.reshape(-1, nf)
    Xz = X - X.mean(axis=1, keepdims=True)
    sd = Xz.std(axis=1, keepdims=True)
    sd[sd == 0] = 1.0
    Xz /= sd

    xcorr_dict = {}
    lag_dict   = {}

    for name, f in features.items():
        f_shifted = np.roll(f, lag_param)
        if lag_param > 0:
            f_shifted[:lag_param] = 0.0
        elif lag_param < 0:
            f_shifted[lag_param:] = 0.0

        fz = (f_shifted - f_shifted.mean()) / (f_shifted.std() + 1e-12)
        r  = (Xz * fz).mean(axis=1)

        xcorr_dict[f'{name}'] = r
        lag_dict[f'{name} lag']       = np.full(N, float(lag_param))

    age_labels = np.repeat(np.arange(n_days) + AGE_OFFSET, n_neurons)
    return xcorr_dict, lag_dict, age_labels


xcorr_dict, lag_dict, age_labels = compute_fixed_lag_correlations(all_resp_mean, features, lag_param)

# %%
# chech if the features are orthogonal (e.g. the dot product is close to zero)
for name1, f1 in features.items():
    for name2, f2 in features.items():
        dot_product = np.dot(f1, f2)
        print(f'Dot product of {name1} and {name2}: {dot_product:.4f}')

# %%
# ─────────────────────────────────────────────────────────────────
# 1 · PSTH heatmaps – representation-drift style
#
# Three sortings (rows fixed across days within each figure):
#   (a) default order
#   (b) sorted by stimulus response on the FIRST day
#   (c) sorted by stimulus response on the LAST day
#
# Style follows the reference figure: narrow greyscale panels,
# minimal axes, day labels only on the first and last panel.
# ─────────────────────────────────────────────────────────────────

STIM_START  = 15
STIM_FRAMES = 60
STIM_END    = STIM_START + STIM_FRAMES   # = 75
CMAP_PSTH   = 'bwr'     # blue-white-red colormap for PSTH heatmaps (diverging, with white at zero)

# Width of each day panel in inches; height scaled to neuron count
PANEL_W = 1.1
PANEL_H = 4.0


def psth_heatmap(all_resp_mean, neuron_order, sort_label,
                 stim_start=STIM_START, stim_end=STIM_END, div_std=True):
    """Plot PSTH heatmaps for every day in the representation-drift style.

    Each day is a narrow panel; rows are neurons in a fixed order;
    columns are time-frames.  Stimulus onset/offset are marked with
    thin vertical lines.  Only the first and last day get P-day labels.

    Parameters
    ----------
    all_resp_mean : ndarray (n_days, n_neurons, n_features)
    neuron_order  : 1-D int array   – fixed row ordering across all days
    sort_label    : str             – used in the y-axis label and title
    stim_start    : int
    stim_end      : int
    div_std       : bool            – whether to divide responses by the global std (for better contrast)
    """
    n_days, n_neurons, n_features = all_resp_mean.shape

    # make a deep copy of all_resp_mean to avoid modifying the original data when dividing by std
    all_resp_mean = np.copy(all_resp_mean)

    # clip to ±2 SD for contrast, then map to [0, 1] for Greys
    flat  = all_resp_mean[:, neuron_order, :]
    vmax  = 15 * np.std(flat)
    vmin  = 15 * -np.std(flat)

    fig, axs = plt.subplots(
        1, n_days,
        figsize=(PANEL_W/2 * n_days, PANEL_H/2),
        dpi=FIG_DPI,
    )
    fig.subplots_adjust(left=0.08, right=0.97, top=0.88,
                        bottom=0.06, wspace=0.04)
    if n_days == 1:
        axs = [axs]

    if div_std:
        # divide each row with the std of that row on that day
            for d in range(n_days):
                for n in range(n_neurons):
                    all_resp_mean[d, n, :] /= np.std(all_resp_mean[d, n, :]) + 1e-12  # add small value to avoid division by zero

    for d, ax in enumerate(axs):
        img = all_resp_mean[d, neuron_order, :]

        ax.imshow(
            img,
            aspect='auto',
            cmap=CMAP_PSTH,
            vmin=vmin,
            vmax=vmax,
            interpolation='nearest',
        )

        # stimulus onset / offset lines
        for xpos in (stim_start - 0.5, stim_end - 0.5):
            ax.axvline(xpos, color='grey', lw=0.7, alpha=0.3, linestyle='--')

        # remove all ticks and spines
        ax.set_xticks([])
        ax.set_yticks([])

        # P-day label above first and last panel only
        if d == 0:
            ax.set_title(f'P{8 + d}', fontsize=9, pad=3)
        elif d == n_days - 1:
            ax.set_title(f'P{8 + d}', fontsize=9, pad=3)
    
    # y-axis label on leftmost panel (rotated, outside)
    axs[0].set_ylabel('Cells', fontsize=8, rotation=90, labelpad=3)
    axs[0].set_yticks([0, n_neurons - 1])
    axs[0].set_yticklabels(['0', str(n_neurons)], fontsize=7)

    # x-axis ticks only on leftmost panel (onset and offset frames)
    axs[0].set_xticks([stim_start, stim_start + (stim_end - stim_start) // 2, stim_end])
    axs[0].set_xticklabels([0, 1, 2], fontsize=6)
    axs[0].set_xlabel('Time (s)', fontsize=8, labelpad=3)

    fig.suptitle(sort_label)
    plt.show()


# (a) default ordering
psth_heatmap(all_resp_mean, np.arange(n_neurons), 'Default sorting')



# ── (d) Sort by 1-D UMAP neuron embedding ────────────────────────
# Each neuron is a data point; timepoints are features.
# We embed the (n_neurons, n_features) matrix per day into 1-D,
# then use those scalar values to sort rows.

import umap as umap_lib  # alias to avoid namespace conflict

def sort_by_neuron_umap(all_resp_mean, ref_day=0, seed=42):
    """Fit a 1-D UMAP on the mean responses of ref_day, return sort order."""
    n_days, n_neurons, nf = all_resp_mean.shape
    X_ref = all_resp_mean[ref_day]          # (n_neurons, n_features)
    reducer_1d = umap_lib.UMAP(
        n_components=1,
        n_neighbors=min(15, n_neurons - 1),
        min_dist=0.1,
        random_state=seed,
    )
    emb_1d = reducer_1d.fit_transform(X_ref).ravel()   # (n_neurons,)
    return np.argsort(emb_1d), emb_1d

# (d-i) sorted by 1-D UMAP embedding of FIRST day
umap_sort_first, umap_emb_first = sort_by_neuron_umap(all_resp_mean, ref_day=0)
psth_heatmap(all_resp_mean, umap_sort_first,
             'First day sorting (UMAP)')

# (d-ii) sorted by 1-D UMAP embedding of LAST day
umap_sort_last, umap_emb_last = sort_by_neuron_umap(all_resp_mean, ref_day=-1)
psth_heatmap(all_resp_mean, umap_sort_last,
             'Last day sorting (UMAP)')

# add now individual day sorting (where umap is computed on each day separately and the sort order is different for each day)
# and show the sorted heatmaps for each day side by side
all_sortings_umap = []
for d in range(n_days):
    umap_sort_day, umap_emb_day = sort_by_neuron_umap(all_resp_mean, ref_day=d)
    # flip the sign if its 3rd 4th or 5th day
    if d in [2, 3, 4]:
        umap_sort_day = umap_sort_day[::-1]
        umap_emb_day = umap_emb_day[::-1]
    all_sortings_umap.append(umap_sort_day)
    
all_resp_mean_sorted_umap = np.zeros_like(all_resp_mean)

for d in range(n_days):
    all_resp_mean_sorted_umap[d] = all_resp_mean[d, all_sortings_umap[d], :]

psth_heatmap(all_resp_mean_sorted_umap, np.arange(n_neurons),
             'Per day sorting (UMAP)')

# %%
# ─────────────────────────────────────────────────────────────────
# 1e · PSTH heatmaps sorted by feature correlation
#
# For each manual feature (step, osc, asymm):
#   sort neurons by their zero-lag Pearson r on the FIRST day
#   sort neurons by their zero-lag Pearson r on the LAST day
#
# xcorr_dict values are (n_days * n_neurons,); extract per-day slices.
# ─────────────────────────────────────────────────────────────────

for feat_name in features.keys():
    # first daya
    
    corr_first   = xcorr_dict[feat_name][:n_neurons]
    sort_first_f = np.argsort(corr_first)[::-1]
    psth_heatmap(all_resp_mean, sort_first_f,
                 f'First-day sorting (corr: {feat_name})')

    # last day
    corr_last    = xcorr_dict[feat_name][(n_days - 1) * n_neurons:]
    sort_last_f  = np.argsort(corr_last)[::-1]
    psth_heatmap(all_resp_mean, sort_last_f,
                 f'Last-day sorting (corr: {feat_name})')

# %%
# ── 2g · Joint-density contour plots for feature pairs ───────────
# (i) All days combined in a single axis per pair.
# (ii) Each day in its own axis per pair (to avoid clutter).

from scipy.stats import gaussian_kde

from scipy.stats import gaussian_kde
import numpy as np

def _kde_contour(
    ax,
    x,
    y,
    color,
    n_grid=100,
    levels=6,
    min_lw=0.6,
    max_lw=3.0,
    alpha=0.95,
):
    """
    Draw contour lines of the 2-D KDE of (x, y),
    with thicker lines for higher density levels.
    """

    # avoid singular covariance
    if np.std(x) < 1e-9 or np.std(y) < 1e-9:
        return

    # KDE
    kde = gaussian_kde(np.vstack([x, y]))

    xi = np.linspace(x.min(), x.max(), n_grid)
    yi = np.linspace(y.min(), y.max(), n_grid)

    Xi, Yi = np.meshgrid(xi, yi)

    Zi = kde(np.vstack([Xi.ravel(), Yi.ravel()])).reshape(Xi.shape)

    # contour levels
    level_values = np.linspace(Zi.min(), Zi.max(), levels + 2)[1:-1]

    # thicker lines for higher density
    linewidths = np.linspace(min_lw, max_lw, len(level_values))

    ax.contour(
        Xi,
        Yi,
        Zi,
        levels=level_values,
        colors=[color],
        linewidths=linewidths,
        alpha=alpha,
    )


def plot_joint_density_combined(corr_dict, age_labels, title='Joint density (all days)', xlim=(-1, 1), ylim=(-1, 1)):
    """One axis per feature pair; all days overlaid, colour = postnatal day."""
    feat_names  = list(corr_dict.keys())
    unique_ages = np.unique(age_labels)
    n_days      = len(unique_ages)
    pairs       = [(i, j) for i in range(len(feat_names))
                           for j in range(i + 1, len(feat_names))]
    n_pairs     = len(pairs)

    fig, axs = plt.subplots(1, n_pairs,
                            figsize=(4.5 * n_pairs, 4.2), dpi=FIG_DPI,
                            squeeze=False)

    for col, (fi, fj) in enumerate(pairs):
        ax   = axs[0, col]
        name_x, name_y = feat_names[fj], feat_names[fi]

        for di, age in enumerate(unique_ages):
            idx   = np.where(age_labels == age)[0]
            color = plt.cm.viridis(di / max(n_days - 1, 1))
            x     = corr_dict[name_x][idx]
            y     = corr_dict[name_y][idx]
            _kde_contour(ax, x, y, color=color)

        ax.set_xlabel(name_x, fontsize=9)
        ax.set_ylabel(name_y, fontsize=9)
        ax.axhline(0, lw=0.4, color='k', ls='--', alpha=0.4)
        ax.axvline(0, lw=0.4, color='k', ls='--', alpha=0.4)
        ax.spines[['top', 'right']].set_visible(False)
        ax.tick_params(labelsize=7)
        ax.set_xlim(xlim)
        ax.set_ylim(ylim)

    # shared colourbar
    sm = plt.cm.ScalarMappable(
        cmap='viridis',
        norm=plt.Normalize(vmin=unique_ages.min(), vmax=unique_ages.max()))
    sm.set_array([])
    fig.colorbar(sm, ax=axs[0, -1], shrink=0.8, label='Postnatal day')
    fig.suptitle(title, fontsize=12)
    plt.tight_layout()
    plt.show()


def plot_joint_density_per_day(corr_dict, age_labels, title='Joint density per day', xlim=(-1, 1), ylim=(-1, 1)):
    """Each day in its own axis; rows = feature pairs, cols = days."""
    feat_names  = list(corr_dict.keys())
    unique_ages = np.unique(age_labels)
    n_days      = len(unique_ages)
    pairs       = [(i, j) for i in range(len(feat_names))
                           for j in range(i + 1, len(feat_names))]
    n_pairs     = len(pairs)

    fig, axs = plt.subplots(n_pairs, n_days,
                            figsize=(2.5 * n_days, 3.5 * n_pairs),
                            dpi=FIG_DPI, squeeze=False)

    for row, (fi, fj) in enumerate(pairs):
        name_x, name_y = feat_names[fj], feat_names[fi]
        for col, (di, age) in enumerate(enumerate(unique_ages)):
            ax    = axs[row, col]
            idx   = np.where(age_labels == age)[0]
            color = plt.cm.viridis(di / max(n_days - 1, 1))
            x     = corr_dict[name_x][idx]
            y     = corr_dict[name_y][idx]
            _kde_contour(ax, x, y, color=color)

            ax.axhline(0, lw=0.4, color='k', ls='--', alpha=0.4)
            ax.axvline(0, lw=0.4, color='k', ls='--', alpha=0.4)
            ax.spines[['top', 'right']].set_visible(False)
            ax.tick_params(labelsize=6)
            ax.set_xlim(xlim)
            ax.set_ylim(ylim)

            if row == 0:
                ax.set_title(f'P{age}', fontsize=9,
                             color=plt.cm.viridis(di / max(n_days - 1, 1)))
            if col == 0:
                ax.set_ylabel(f'{name_y}\nvs {name_x}', fontsize=7)
            if row == n_pairs - 1:
                ax.set_xlabel(name_x, fontsize=7)

    fig.suptitle(title, fontsize=12)
    plt.tight_layout()
    plt.show()


# plot_joint_density_combined(
#     corr_dict, age_labels,
#     'Zero-lag feature pair joint density (all days combined)')

# plot_joint_density_per_day(
#     corr_dict, age_labels,
#     'Zero-lag feature pair joint density (per day)')

plot_joint_density_combined(
    xcorr_dict, age_labels,
    f'Fixed-lag (={lag_param} frames) feature pair joint density (all days combined)', xlim=(-1, 1), ylim=(-1, 1))

plot_joint_density_per_day(
    xcorr_dict, age_labels,
    f'Fixed-lag (={lag_param} frames) feature pair joint density (per day)', xlim=(-1, 1), ylim=(-1, 1))

# %%
# ── 2f · Violin plots of feature correlations across days ────────
# Clean violin plots (like Fig D), viridis colorscheme, grey median dot.
# 5 random neurons connected by grey lines to show longitudinal structure.

def plot_feature_violins(corr_dict, age_labels, all_resp_mean, ex_neurons=None, seed=0, ylim=None):
    """Violin plot of each feature correlation distribution per postnatal day.

    Parameters
    ----------
    corr_dict     : dict {name: 1-D float (n_days*n_neurons,)}
    age_labels    : 1-D int array
    all_resp_mean : ndarray (n_days, n_neurons, n_features)  – used for n_neurons
    seed          : random seed for picking example neurons
    """
    rng         = np.random.default_rng(seed)
    feat_names  = list(corr_dict.keys())
    unique_ages = np.unique(age_labels)
    n_days      = len(unique_ages)
    n_neurons   = all_resp_mean.shape[1]
    n_feats     = len(feat_names)

    # use provided neuron indices or pick random ones
    eg_neurons = ex_neurons if ex_neurons is not None else rng.choice(n_neurons, size=5, replace=False)

    # viridis colours per day
    day_colors = [plt.cm.viridis(d / max(n_days - 1, 1)) for d in range(n_days)]

    fig, axs = plt.subplots(1, n_feats,
                            figsize=(2.5 * n_feats, 2.5), dpi=FIG_DPI,
                            sharey=False)
    if n_feats == 1:
        axs = [axs]

    for ax, name in zip(axs, feat_names):
        # build per-day data lists
        day_data = []
        for age in unique_ages:
            idx = np.where(age_labels == age)[0]
            day_data.append(corr_dict[name][idx])

        # matplotlib violin
        parts = ax.violinplot(
            day_data,
            positions=np.arange(n_days),
            widths=0.65,
            showmeans=False,
            showmedians=False,
            showextrema=False,
        )

        # colour each violin body by day (viridis)
        for di, pc in enumerate(parts['bodies']):
            pc.set_facecolor(day_colors[di])
            pc.set_alpha(0.75)
            pc.set_edgecolor('none')

        # grey median dot
        for di, data in enumerate(day_data):
            med = np.median(data)
            ax.scatter(di, med, color='#555555', s=30, zorder=5)

        # ── longitudinal lines for 5 random neurons ──────────────
        for nrn in eg_neurons:
            vals = [corr_dict[name][np.where(age_labels == age)[0][nrn]]
                    for age in unique_ages]
            ax.plot(np.arange(n_days), vals,
                    color='grey', lw=0.9, alpha=0.55, zorder=4)

        # axes cosmetics
        ax.set_xticks(np.arange(n_days))
        ax.set_xticklabels([f'P{a}' for a in unique_ages], fontsize=9)
        ax.set_ylabel('Pearson r', fontsize=9)
        ax.set_title(name, fontsize=11)
        ax.axhline(0, color='k', lw=0.5, ls='--', alpha=0.5)
        ax.spines[['top', 'right']].set_visible(False)
        ax.tick_params(labelsize=8)
        if ylim is not None:
            ax.set_ylim(ylim)
        # only put 3 ticks - min, 0, max
        ax.set_yticks([round(ax.get_ylim()[0], 1), 0, round(ax.get_ylim()[1], 1)])

    fig.suptitle('Feature correlations across postnatal days', fontsize=12)
    plt.tight_layout()
    plt.show()


plot_feature_violins(xcorr_dict, age_labels, all_resp_mean, ex_neurons=ex_nrn_idxs)
plot_feature_violins(xcorr_dict, age_labels, all_resp_mean, ex_neurons=ex_nrn_idxs, ylim=(-1, 1))

# %%
# ── 2h · 3-D scatter of feature correlations (multiple projections) ──────────
# For three features we can directly show the 3-D joint distribution.
# Four subplots show: the 3-D view + the three 2-D projections.

from mpl_toolkits.mplot3d import Axes3D  # noqa: F401

def plot_3d_feature_scatter(corr_dict, age_labels,
                             title='3-D feature correlation scatter'):
    """3-D scatter + 2-D projections, colour = postnatal day (viridis).

    Requires exactly 3 features (step, osc, asymm).
    """
    feat_names  = list(corr_dict.keys())
    if len(feat_names) < 3:
        print('Need ≥ 3 features for 3-D scatter.')
        return

    fn = feat_names[:3]
    x, y, z = [corr_dict[n] for n in fn]

    unique_ages = np.unique(age_labels)
    n_days      = len(unique_ages)
    norm        = plt.Normalize(vmin=unique_ages.min(), vmax=unique_ages.max())
    colors      = plt.cm.viridis(norm(age_labels))

    fig = plt.figure(figsize=(14, 3.8), dpi=FIG_DPI)

    # ── (i) 3-D view ──────────────────────────────────────────────
    ax3d = fig.add_subplot(1, 4, 1, projection='3d')
    ax3d.scatter(x, y, z, c=colors, s=3, alpha=0.5, rasterized=True)
    ax3d.set_xlabel(fn[0], fontsize=7, labelpad=2)
    ax3d.set_ylabel(fn[1], fontsize=7, labelpad=2)
    ax3d.set_zlabel(fn[2], fontsize=7, labelpad=2)
    ax3d.tick_params(labelsize=5)
    ax3d.set_title('3-D view', fontsize=9)

    # ── (ii–iv) 2-D projections ───────────────────────────────────
    proj_pairs = [(0, 1), (0, 2), (1, 2)]
    for k, (pi, pj) in enumerate(proj_pairs):
        ax = fig.add_subplot(1, 4, k + 2)
        ax.scatter(corr_dict[fn[pi]], corr_dict[fn[pj]],
                   c=colors, s=2, alpha=0.45, rasterized=True)
        ax.set_xlabel(fn[pi], fontsize=8)
        ax.set_ylabel(fn[pj], fontsize=8)
        ax.axhline(0, lw=0.4, color='k', ls='--', alpha=0.4)
        ax.axvline(0, lw=0.4, color='k', ls='--', alpha=0.4)
        ax.spines[['top', 'right']].set_visible(False)
        ax.tick_params(labelsize=6)
        ax.set_title(f'{fn[pi]} vs {fn[pj]}', fontsize=8)

    # shared colourbar
    sm = plt.cm.ScalarMappable(cmap='viridis', norm=norm)
    sm.set_array([])
    fig.colorbar(sm, ax=fig.axes, shrink=0.6, pad=0.02,
                 label='Postnatal day')

    fig.suptitle(title, fontsize=11, y=1.01)
    plt.tight_layout()
    plt.show()


plot_3d_feature_scatter(xcorr_dict, age_labels,
                        f'Fixed-lag (={lag_param} frames) features – 3-D scatter + projections')

# %%
FIG_DPI = 400

# %%
def plot_3d_feature_scatter_multi_view(corr_dict, age_labels,
                                       title='3-D feature correlation scatter – Multi-view',
                                       views=None):
    """3-D scatter with multiple 3D projections.
    If `views` is None, uses default views (main, front, top, side).
    If `views` is a list of (elev, azim) tuples, uses those.
    """
    feat_names = list(corr_dict.keys())
    if len(feat_names) < 3:
        print('Need ≥ 3 features for 3-D scatter.')
        return

    fn = feat_names[:3]
    x, y, z = [corr_dict[n] for n in fn]

    unique_ages = np.unique(age_labels)
    norm = plt.Normalize(vmin=unique_ages.min(), vmax=unique_ages.max())
    colors = plt.cm.viridis(norm(age_labels))

    # Set default views if none provided
    if views is None:
        views = [
            (30, 45),   # Main view
            (90, 0),    # Front (XY)
            (0, 0),     # Top (XZ)
            (90, 90)    # Side (YZ)
        ]

    fig = plt.figure(figsize=(16, 4), dpi=FIG_DPI)

    for i, (elev, azim) in enumerate(views):
        ax = fig.add_subplot(1, len(views), i+1, projection='3d')
        ax.scatter(x, y, z, c=colors, s=3, alpha=0.5, rasterized=True)
        ax.set_xlabel(fn[0], fontsize=7, labelpad=2)
        ax.set_ylabel(fn[1], fontsize=7, labelpad=2)
        ax.set_zlabel(fn[2], fontsize=7, labelpad=2)
        ax.view_init(elev=elev, azim=azim)
        ax.tick_params(labelsize=5)
        ax.set_title(f'View {i+1}: elev={elev}, azim={azim}', fontsize=8)

    # Shared colourbar
    sm = plt.cm.ScalarMappable(cmap='viridis', norm=norm)
    sm.set_array([])
    fig.colorbar(sm, ax=fig.axes, shrink=0.6, pad=0.02, label='Postnatal day')

    fig.suptitle(title, fontsize=11, y=1.01)
    plt.tight_layout()
    plt.show()

# %%
plot_3d_feature_scatter_multi_view(
    xcorr_dict, age_labels,
    f'Fixed-lag (={lag_param} frames) features – 3-D scatter multi-view'
)

# %%
import numpy as np
np.random.seed(42)  # For reproducibility
random_views = [(np.random.randint(0, 90), np.random.randint(0, 360)) for _ in range(4)]
random_views[0] = (30, 45)  # Keep the first view as the main view for consistency

plot_3d_feature_scatter_multi_view(
    xcorr_dict, age_labels,
    f'Fixed-lag (={lag_param} frames) features – 3-D scatter multi-view (Random)',
    views=random_views
)

# %%
if animate_3d_rotation:
    import matplotlib.animation as animation
    from mpl_toolkits.mplot3d import Axes3D   # noqa: F401

    # ── Build the 3-D scatter (same style as plot_3d_feature_scatter_multi_view) ──
    feat_names = list(xcorr_dict.keys())[:3]
    x, y, z    = [xcorr_dict[n] for n in feat_names]

    unique_ages = np.unique(age_labels)
    norm        = plt.Normalize(vmin=unique_ages.min(), vmax=unique_ages.max())
    colors      = plt.cm.viridis(norm(age_labels))

    fig = plt.figure(figsize=(6, 6), dpi=150)
    ax  = fig.add_subplot(111, projection='3d')
    ax.scatter(x, y, z, c=colors, s=3, alpha=0.5, rasterized=True)
    ax.set_xlabel(feat_names[0], fontsize=8, labelpad=4)
    ax.set_ylabel(feat_names[1], fontsize=8, labelpad=4)
    ax.set_zlabel(feat_names[2], fontsize=8, labelpad=4)
    ax.tick_params(labelsize=6)

    sm = plt.cm.ScalarMappable(cmap='viridis', norm=norm)
    sm.set_array([])
    fig.colorbar(sm, ax=ax, shrink=0.6, pad=0.12, label='Postnatal day')

    # ── Trajectory for example neuron 33 ─────────────────────────────────────────
    ex_nrn = 33
    traj_x = [x[d * n_neurons + ex_nrn] for d in range(n_days)]
    traj_y = [y[d * n_neurons + ex_nrn] for d in range(n_days)]
    traj_z = [z[d * n_neurons + ex_nrn] for d in range(n_days)]
    ax.plot(traj_x, traj_y, traj_z, color='grey', lw=1.2, alpha=0.7, zorder=5)
    ax.scatter(traj_x, traj_y, traj_z,
               c=unique_ages, cmap='viridis',
               vmin=unique_ages.min(), vmax=unique_ages.max(),
               s=30, zorder=6, edgecolors='none')

    # ── Animate: full 360° azimuth rotation at fixed elevation ────────────────────
    def _update(azim):
        ax.view_init(elev=25, azim=azim)
        return [ax]

    anim = animation.FuncAnimation(
        fig, _update,
        frames=np.arange(0, 360, 1),   # 360 frames → 12 s at 30 fps
        interval=33, blit=False,
    )

    save_path = '/Users/jure/Documents/cossart_lab/code/photostim_deve/features_3d_scatter.mp4'
    writer = animation.FFMpegWriter(fps=30, bitrate=2000)
    anim.save(save_path, writer=writer, dpi=150)
    plt.close(fig)
    print(f'Saved → {save_path}')

# %% [markdown]
# ## 4 · UMAP coloured by feature correlations & optimal lags
#
# Re-use the existing `emb_umap_mn` embedding (neurons × days flattened) and
# colour each point by:
# - zero-lag Pearson r with each template feature
# - max-xcorr value for each feature
# - optimal lag for each feature

# %%
# ─────────────────────────────────────────────────────────────────
# 4 · UMAP colour-coded by feature correlations and optimal lags
#
# emb_umap_mn  shape (n_days * n_neurons, 2)  – existing embedding
# xcorr_dict   fixed-lag correlations (from §2)
# ─────────────────────────────────────────────────────────────────

# Colourmap choices: diverging for correlations, sequential for lags
CMAP_CORR = 'PiYG'   # −1 (blue) → 0 → +1 (red)


def umap_coloured(emb, values, label, cmap, vmin, vmax, title):
    """Scatter the UMAP embedding coloured by a scalar field.

    Parameters
    ----------
    emb    : ndarray (N, 2)
    values : ndarray (N,)
    label  : str  – colourbar label
    cmap   : str or Colormap
    vmin, vmax : float  – colour scale limits
    title  : str
    """
    fig, ax = plt.subplots(figsize=(3.5, 2.5), dpi=FIG_DPI)
    sc = ax.scatter(emb[:, 0], emb[:, 1],
                    c=values, cmap=cmap,
                    vmin=vmin, vmax=vmax,
                    s=5, alpha=0.7, rasterized=True)
    cbar = fig.colorbar(sc, ax=ax, shrink=0.8, pad=0.02, ticks=[vmin, vmin/2, 0, vmax/2, vmax])
    cbar.set_label(label, fontsize=10)
    cbar.ax.tick_params(labelsize=8)
    ax.set_title(title, fontsize=11)
    ax.axis('off')
    plt.tight_layout()
    plt.show()



# ── 4b · Max cross-correlation values ────────────────────────────

for name, vals in xcorr_dict.items():
    umap_coloured(
        emb_umap_mn, vals,
        label=f'Corr. ({name})',
        cmap=CMAP_CORR, vmin=-1, vmax=1,
        title='',
    )

name = 'osc'
vals = xcorr_dict[name]

umap_coloured(
    emb_umap_mn, vals,
    label=f'Corr. ({name})',
    cmap=CMAP_CORR, vmin=-0.5, vmax=0.5,
    title='',
)

# %% [markdown]
# ## 6 · Stability plots for manually crafted features
#
# Each stability plot is an **n_days × n_days** symmetric matrix.
# Element (i, j) is the **Pearson correlation across cells** between the
# feature-score vectors of day i and day j.
#
# - A value near 1 means the *same* neurons show a strong response to that feature on both days (stable representation).
# - A value near 0 means the responding population has shuffled between those two days.
# - Three matrices correspond to the three manual templates (step, osc, asymm).
# - A fourth matrix uses the **full PSTH** (all time-points concatenated per neuron, then correlated across cells) to capture global population-level stability.

# %%
# ─────────────────────────────────────────────────────────────────
# 6 · Stability plots
#
# For each feature f:
#   v_i  = xcorr_dict[f][i*n_neurons : (i+1)*n_neurons]  (fixed-lag Pearson r per cell, day i)
#   stab[i, j] = Pearson r of v_i and v_j  (across n_neurons cells)
#
# Full-PSTH stability:
#   Flatten all_resp_mean[d] → (n_neurons × n_features,) per day.
#   stab[i, j] = Pearson r of those two long vectors.
#   Equivalent to asking: "do the same neurons respond the same way
#   at the same timepoints across day i and day j?"
# ─────────────────────────────────────────────────────────────────

def stability_matrix(vecs_per_day):
    """n_days × n_days Pearson correlation matrix.

    vecs_per_day : list of 1-D arrays (all same length, ≥ n_neurons)
    """
    n = len(vecs_per_day)
    S = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            S[i, j] = np.corrcoef(vecs_per_day[i], vecs_per_day[j])[0, 1]
    return S


def plot_stability_matrices(stab_dict, ages):
    """Plot one stability matrix per feature side-by-side.

    stab_dict : dict {label: ndarray (n_days, n_days)}
    ages      : 1-D int array – postnatal ages for axis tick labels
    """
    n_mats   = len(stab_dict)
    day_labs = [f'P{a}' for a in ages]

    fig, axs = plt.subplots(1, n_mats,
                            figsize=(3.2 * n_mats, 3.0),
                            dpi=FIG_DPI)
    if n_mats == 1:
        axs = [axs]

    for ax, (label, S) in zip(axs, stab_dict.items()):
        im = ax.imshow(S, cmap='bwr', vmin=-1, vmax=1,
                       interpolation='nearest', aspect='equal')
        for i in range(S.shape[0]):
            for j in range(S.shape[1]):
                ax.text(j, i, f'{S[i, j]:.2f}',
                        ha='center', va='center', fontsize=6.5,
                        color='k' if abs(S[i, j]) < 0.6 else 'w')
        ax.set_xticks(np.arange(len(ages)))
        ax.set_yticks(np.arange(len(ages)))
        ax.set_xticklabels(day_labs, fontsize=8, rotation=45, ha='right')
        ax.set_yticklabels(day_labs, fontsize=8)
        ax.set_title(label, fontsize=10)
        fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04,
                     label='Pearson r' if ax is axs[-1] else '')

    fig.suptitle('Stability of feature representation across days\n'
                 '(Pearson r of per-cell scores between each pair of days)',
                 fontsize=10)
    plt.tight_layout()
    plt.show()


# ── Build stability matrices ──────────────────────────────────────

stab_dict = {}

# (a) Three manual features – score per cell = fixed-lag Pearson r with template
for feat_name, feat_vals in xcorr_dict.items():
    vecs = [feat_vals[d * n_neurons:(d + 1) * n_neurons]
            for d in range(n_days)]
    stab_dict[feat_name] = stability_matrix(vecs)

# (b) Full PSTH – flatten all timepoints; one long vector per day
stab_dict['full PSTH'] = stability_matrix(
    [all_resp_mean[d].flatten() for d in range(n_days)]
)

ages_arr = np.arange(n_days) + AGE_OFFSET
plot_stability_matrices(stab_dict, ages_arr)


# ── Bonus: stability vs day-lag line plot ─────────────────────────

fig, ax = plt.subplots(figsize=(5, 3.5), dpi=FIG_DPI)
feat_colors_stab = ['C0', 'C1', 'C2', 'C3']

for (feat_name, S), color in zip(stab_dict.items(), feat_colors_stab):
    lags      = np.arange(n_days)
    mean_stab = np.array([
        np.mean([S[i, j] for i in range(n_days)
                          for j in range(n_days) if abs(i - j) == lag])
        for lag in lags
    ])
    ax.plot(lags, mean_stab, marker='o', label=feat_name, color=color, lw=2)

ax.set_xlabel('Day lag |i − j|', fontsize=10)
ax.set_ylabel('Mean Pearson r (across cells)', fontsize=10)
ax.set_title('Population stability vs temporal lag', fontsize=11)
ax.set_xticks(lags)
ax.set_xticklabels([f'+{l}d' for l in lags], fontsize=9)
ax.axhline(0, lw=0.5, color='k', ls='--', alpha=0.5)
ax.legend(fontsize=8, frameon=False)
ax.spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.show()

# %%
# now plot 24

# %%
# ─────────────────────────────────────────────────────────────────
# Modification 1 · 3-D multi-view with optional C0 / age colourmap
# ─────────────────────────────────────────────────────────────────

def plot_3d_feature_scatter_multi_view_v2(corr_dict, age_labels,
                                           title='3-D feature correlation scatter – Multi-view',
                                           views=None,
                                           color_by_age=True):
    """3-D scatter with multiple 3D projections.

    Parameters
    ----------
    color_by_age : bool
        True  → viridis colormap keyed to postnatal day (original behaviour)
        False → all points in C0 (single colour, no colorbar)
    """
    feat_names = list(corr_dict.keys())
    if len(feat_names) < 3:
        print('Need >= 3 features for 3-D scatter.')
        return

    fn = feat_names[:3]
    x, y, z = [corr_dict[n] for n in fn]

    if color_by_age:
        unique_ages = np.unique(age_labels)
        norm        = plt.Normalize(vmin=unique_ages.min(), vmax=unique_ages.max())
        colors      = plt.cm.viridis(norm(age_labels))
    else:
        colors = None

    if views is None:
        views = [
            (30,  45),   # Main view
            (90,   0),   # Front (XY)
            ( 0,   0),   # Top  (XZ)
            (90,  90),   # Side (YZ)
        ]

    fig = plt.figure(figsize=(16, 4), dpi=FIG_DPI)

    for i, (elev, azim) in enumerate(views):
        ax = fig.add_subplot(1, len(views), i + 1, projection='3d')
        if color_by_age:
            ax.scatter(x, y, z, c=colors, s=3, alpha=0.5, rasterized=True)
        else:
            ax.scatter(x, y, z, color='C0', s=3, alpha=0.5, rasterized=True)
        ax.set_xlabel(fn[0], fontsize=7, labelpad=2)
        ax.set_ylabel(fn[1], fontsize=7, labelpad=2)
        ax.set_zlabel(fn[2], fontsize=7, labelpad=2)
        ax.view_init(elev=elev, azim=azim)
        ax.tick_params(labelsize=5)
        ax.set_title(f'View {i+1}: elev={elev}, azim={azim}', fontsize=8)

    if color_by_age:
        sm = plt.cm.ScalarMappable(cmap='viridis', norm=norm)
        sm.set_array([])
        fig.colorbar(sm, ax=fig.axes, shrink=0.6, pad=0.02, label='Postnatal day')

    fig.suptitle(title, fontsize=11, y=1.01)
    plt.tight_layout()
    plt.show()


# Call with single colour (C0)
plot_3d_feature_scatter_multi_view_v2(
    xcorr_dict, age_labels,
    title=f'Fixed-lag (={lag_param} frames) features – 3-D multi-view (C0)',
    color_by_age=False,
)

# Call with age colourmap (viridis)
plot_3d_feature_scatter_multi_view_v2(
    xcorr_dict, age_labels,
    title=f'Fixed-lag (={lag_param} frames) features – 3-D multi-view (age coloured)',
    color_by_age=True,
)

# %%
def plot_neuron_psth(neuron_resp, neuron_idx, age_labels, xcorr_dict,
                     features=None, feature_overlay=None, lag_param=0):
    """Per-day PSTH panels for a single example neuron.

    Parameters
    ----------
    neuron_resp     : ndarray (n_days, n_timepoints)
    neuron_idx      : int
    age_labels      : 1-D int array  – used to recover postnatal ages
    features        : dict or None   – feature templates
    feature_overlay : str or None    – name of feature to overlay on each panel
    lag_param       : int            – time offset applied to the overlay template
    """
    unique_ages = np.unique(age_labels)
    n_days      = len(unique_ages)

    fig_p, axes_p = plt.subplots(1, n_days,
                                  figsize=(1.5 * n_days, 1.5),
                                  dpi=FIG_DPI, sharey=True, sharex=True)
    if n_days == 1:
        axes_p = [axes_p]
    
    curr_max = 0 
    for d, ax_p in enumerate(axes_p):
        corr = xcorr_dict[feature_overlay][d * n_neurons + neuron_idx] if feature_overlay in xcorr_dict and xcorr_dict is not None else 0
        title = f'P{unique_ages[d]} (r={corr:.2f})' if feature_overlay in xcorr_dict and xcorr_dict is not None else f'P{unique_ages[d]}'
        color_d = plt.cm.viridis(d / max(n_days - 1, 1))
        ax_p.plot(neuron_resp[d], color=color_d, lw=3.5)
        ax_p.axhline(0, color='k', lw=2, alpha=0.2, zorder=0)
        ax_p.axis('off')
        ax_p.set_title(title, fontsize=7, color=color_d, pad=2)
        curr_max = max(curr_max, np.max(neuron_resp[d]))

    if feature_overlay is not None and features is not None and feature_overlay in features:
        for ax_p in axes_p:
            t_overlay = np.arange(len(features[feature_overlay])) + lag_param
            # now normalise feature to match the PSTH scale (optional, but makes it easier to compare shapes)
            feat_scaled = features[feature_overlay] * curr_max / np.max(features[feature_overlay])
            ax_p.plot(t_overlay, feat_scaled,
                        color='k', lw=1.0, alpha=0.7, zorder=5)
        # set ylim to +- max
        for ax_p in axes_p:
            ax_p.set_ylim(-curr_max * 1.1, curr_max * 1.1)

    fig_p.suptitle(f'Neuron {neuron_idx} – trial-averaged responses',
                   fontsize=8, y=1.05)
    plt.tight_layout()
    plt.show()

# %%
ex_nrn_idxs_expanded = ex_nrn_idxs + [57, 1, 22, 16, 50, 20, 92]  # Add more example neurons to plot

# %%
for ex_nrn_idx in ex_nrn_idxs_expanded:
    plot_neuron_psth(all_resp_mean[:, ex_nrn_idx, :], ex_nrn_idx, age_labels, xcorr_dict)

# %%
for ex_nrn_idx in ex_nrn_idxs:
    for feat_name in features.keys():
        plot_neuron_psth(all_resp_mean[:, ex_nrn_idx, :], ex_nrn_idx, age_labels,
                         xcorr_dict=xcorr_dict, features=features, feature_overlay=feat_name, lag_param=lag_param)

# %%
# ─────────────────────────────────────────────────────────────────
# Modification 2 · 2-D scatter grid: single-pair panels, feature
# mini-plots as axis labels, optional C0/age colour, and optional
# per-cell longitudinal trajectory + daily PSTHs as a separate figure.
# ─────────────────────────────────────────────────────────────────

from matplotlib.offsetbox import AnnotationBbox, OffsetImage
from mpl_toolkits.axes_grid1.inset_locator import inset_axes


def _feature_inset_axes(fig, ax, side, features, feat_name, size="10%", pad=0.05):
    """Add a mini-line-plot of a feature template as an axis label.

    side : 'bottom' or 'left'
    """
    f = features[feat_name]
    t = np.arange(len(f))

    if side == 'bottom':
        ax_ins = inset_axes(ax, width="25%", height=size,
                            loc='lower center',
                            bbox_to_anchor=(0, -0.22, 1, 1),
                            bbox_transform=ax.transAxes,
                            borderpad=0)
        ax_ins.plot(t, f, color='k', lw=1.0)
    else:   # left – rotated 90° (amplitude on x, time on y)
        ax_ins = inset_axes(ax, width=size, height="25%",
                            loc='center left',
                            bbox_to_anchor=(-0.22, 0, 1, 1),
                            bbox_transform=ax.transAxes,
                            borderpad=0)
        ax_ins.plot(f, t[::-1], color='k', lw=1.0)

    ax_ins.axis('off')
    return ax_ins





def plot_2d_scatter_pairs(corr_dict, age_labels, features,
                          color_by_age=True, xlim=(-1, 1), ylim=(-1, 1),
                          ex_neuron=None):
    """One scatter per feature pair with mini feature-template axis labels.

    color_by_age : bool
        True  → viridis colormap by postnatal day
        False → all points in C0
    ex_neuron : int or None
        If given, draw the longitudinal trajectory for this neuron
        (grey line + viridis dots).
    """
    feat_names  = list(corr_dict.keys())
    unique_ages = np.unique(age_labels)
    n_days      = len(unique_ages)
    n_neurons   = len(age_labels) // n_days
    pairs       = [(i, j) for i in range(len(feat_names))
                           for j in range(i + 1, len(feat_names))]

    has_traj = ex_neuron is not None

    if color_by_age:
        norm   = plt.Normalize(vmin=unique_ages.min(), vmax=unique_ages.max())
        colors = plt.cm.viridis(norm(age_labels))
    else:
        colors = 'C0'

    scatter_alpha = 0.25 if has_traj else 1
    scatter_size = 0.25 if has_traj else 1

    for fi, fj in pairs:
        name_x = feat_names[fi]
        name_y = feat_names[fj]
        x_vals = corr_dict[name_x]
        y_vals = corr_dict[name_y]

        fig, ax = plt.subplots(figsize=(2.5, 2.5), dpi=FIG_DPI)
        fig.subplots_adjust(left=0.22, bottom=0.22, right=0.92, top=0.88)

        ax.scatter(x_vals, y_vals, c=colors, s=scatter_size, alpha=scatter_alpha,
                   rasterized=True,
                   **(dict(vmin=unique_ages.min(), vmax=unique_ages.max(),
                           cmap='viridis') if color_by_age else {}))

        if has_traj:
            traj_x = [corr_dict[name_x][d * n_neurons + ex_neuron] for d in range(n_days)]
            traj_y = [corr_dict[name_y][d * n_neurons + ex_neuron] for d in range(n_days)]
            ax.plot(traj_x, traj_y, color='grey', lw=1.0, alpha=0.55, zorder=3)
            ax.scatter(traj_x, traj_y,
                       c=np.arange(n_days), cmap='viridis',
                       vmin=0, vmax=n_days - 1,
                       s=25, zorder=4, edgecolors='none')

        ax.set_xlim(xlim);  ax.set_ylim(ylim)
        ax.axhline(0, lw=0.4, color='k', ls='--', alpha=0.4)
        ax.axvline(0, lw=0.4, color='k', ls='--', alpha=0.4)
        ax.spines[['top', 'right']].set_visible(False)
        ax.tick_params(labelsize=7)
        ax.set_xlabel('', fontsize=8)
        ax.set_ylabel('', fontsize=8)
        ax.set_xticks([-1, 0, 1])
        ax.set_yticks([-1, 0, 1])

        nx = name_x[:-8] if name_x.endswith(')') else name_x
        ny = name_y[:-8] if name_y.endswith(')') else name_y

        if nx in features:
            _feature_inset_axes(fig, ax, 'bottom', features, nx)
        else:
            ax.set_xlabel(nx, fontsize=8)
        if ny in features:
            _feature_inset_axes(fig, ax, 'left', features, ny)
        else:
            ax.set_ylabel(ny, fontsize=8)

        if color_by_age:
            sm = plt.cm.ScalarMappable(cmap='viridis',
                                        norm=plt.Normalize(unique_ages.min(),
                                                           unique_ages.max()))
            sm.set_array([])
            # fig.colorbar(sm, ax=ax, shrink=0.7, label='Postnatal day')

        plt.show()


# ── Mod-2 calls ───────────────────────────────────────────────────

# Single scatter, C0
plot_2d_scatter_pairs(xcorr_dict, age_labels, features, color_by_age=False)

# Single scatter, age coloured
plot_2d_scatter_pairs(xcorr_dict, age_labels, features, color_by_age=True)

# Trajectory scatter + PSTH panels per example neuron
for ex_nrn_idx in ex_nrn_idxs:
    plot_2d_scatter_pairs(xcorr_dict, age_labels, features,
                          color_by_age=True, ex_neuron=ex_nrn_idx)
    plot_neuron_psth(all_resp_mean[:, ex_nrn_idx, :], ex_nrn_idx, age_labels, xcorr_dict)

# %%
# now make a function for a neuron index (60) and plot it with the overlay of some feature across all days (add text whcih correspnds to the feature name) and then plot the PSTH of that neuron across all days in a separate figure with the same colour scheme as the scatter plot (viridis) and add text which corresponds to the feature correlation.
def plot_resp_feature_overlay(ex_nrn_idx, feature_name):
    """Plot the trajectory of one neuron in the feature scatter, plus its PSTH.

    ex_nrn_idx : int
        Index of the example neuron to plot (0-based within each day)
    feature_name : str
        Name of the feature to overlay (must be a key in xcorr_dict)
    """
    if feature_name not in xcorr_dict:
        print(f'Feature "{feature_name}" not found in xcorr_dict.')
        return

    feat_vals = xcorr_dict[feature_name]
    unique_ages = np.unique(age_labels)
    n_days = len(unique_ages)
    n_neurons = len(age_labels) // n_days
    

# now plot for neuron index 60 all three features
for ex_nrn_idx in [60]:  # Example neuron index
    for feature_name in xcorr_dict.keys():
        plot_resp_feature_overlay(ex_nrn_idx, feature_name)

# %%
from scipy.spatial import cKDTree
import string

GRID_N = 5

def plot_umap_grid_responses(emb, all_resp_mean, labels, n_neurons,
                              grid_n=GRID_N, title='UMAP grid',
                              vmin_resp=-1, vmax_resp=3,
                              lag_param=0, stim_start=STIM_START, stim_end=STIM_END):
    n_days, _, n_features = all_resp_mean.shape

    x_min, x_max = emb[:, 0].min(), emb[:, 0].max()
    y_min, y_max = emb[:, 1].min(), emb[:, 1].max()
    margin = 0.001
    x_min -= margin * (x_max - x_min);  x_max += margin * (x_max - x_min)
    y_min -= margin * (y_max - y_min);  y_max += margin * (y_max - y_min)

    gx = np.linspace(x_min, x_max, grid_n)
    gy = np.linspace(y_max, y_min, grid_n)   # top-to-bottom so PSTH rows match UMAP
    GX, GY = np.meshgrid(gx, gy)
    grid_pts = np.column_stack([GX.ravel(), GY.ravel()])

    tree = cKDTree(emb)
    _, nn_idx = tree.query(grid_pts)

    n_pts    = grid_n ** 2
    alphabet = list(string.ascii_lowercase)
    lbl_list = [(alphabet[k] if k < 26 else alphabet[k // 26 - 1] + alphabet[k % 26])
                for k in range(n_pts)]

    fig = plt.figure(figsize=(4, 4 + grid_n * 0.8), dpi=FIG_DPI)
    gs  = fig.add_gridspec(
        1 + grid_n, grid_n,
        height_ratios=[8] + [1] * grid_n,
        hspace=0.4, wspace=0.3,
        left=0.04, right=0.97, top=0.94, bottom=0.03,
    )

    # ── UMAP scatter ─────────────────────────────────────────────
    ax_umap = fig.add_subplot(gs[0, :])
    # do viridis scatter but with very low alpha, so we can see the grid points clearly on top
    ax_umap.scatter(emb[:, 0], emb[:, 1],
                    color=plt.cm.viridis(labels_mn / max(n_days - 1, 1)), s=1, alpha=0.2, zorder=1, rasterized=True)

    for k in range(n_pts):
        nn  = nn_idx[k]
        lbl = lbl_list[k]
        ax_umap.text(*emb[nn], lbl, fontsize=7, ha='center', va='center',
                     color='k', fontweight='bold', zorder=4)

    ax_umap.axis('off')
    ax_umap.set_title(title, fontsize=11)

    # ── PSTH sub-panels ──────────────────────────────────────────
    for k in range(n_pts):
        nn  = nn_idx[k]
        lbl = lbl_list[k]
        day = int(labels[nn])
        nrn = nn - day * n_neurons

        row = k // grid_n
        col = k  % grid_n
        ax_p = fig.add_subplot(gs[1 + row, col])

        color_d = plt.cm.viridis(day / max(n_days - 1, 1))
        ax_p.plot(all_resp_mean[day, nrn], color=color_d, lw=2)
        ax_p.set_ylim(vmin_resp, vmax_resp)
        ax_p.axhline(0, color='k', lw=0.4, alpha=0.2)
        # ax_p.axvline(stim_start + lag_param, color='k', lw=0.4, alpha=0.2)
        # ax_p.axvline(stim_end   + lag_param, color='k', lw=0.4, alpha=0.2)
        ax_p.axis('off')
        ax_p.set_title(f'{lbl}  P{day + AGE_OFFSET}', fontsize=7, pad=2, color=color_d)

    plt.show()


plot_umap_grid_responses(
    emb_umap_mn, all_resp_mean, labels_mn, n_neurons,
    title='UMAP – trial-averaged responses (mean grid)',
    lag_param=lag_param,
)

# %%
def plot_umap_grid_responses_st(emb, all_resp_flat, day_labels, n_days,
                                 grid_n=GRID_N, title='UMAP ST grid',
                                 n_nn=60, vmin_resp=-1, vmax_resp=10,
                                 lag_param=0, stim_start=STIM_START, stim_end=STIM_END):
    """Single-trial UMAP grid viewer.

    For each grid point the n_nn closest embedding points are found and
    their raw single-trial responses averaged into one PSTH panel.

    emb           : ndarray (N, 2)        single-trial UMAP embedding
    all_resp_flat : ndarray (N, n_features) matching flattened single-trial data
    day_labels    : 1-D int array (N,)    day index per embedding point
    """
    x_min, x_max = emb[:, 0].min(), emb[:, 0].max()
    y_min, y_max = emb[:, 1].min(), emb[:, 1].max()
    margin = 0.001
    x_min -= margin * (x_max - x_min);  x_max += margin * (x_max - x_min)
    y_min -= margin * (y_max - y_min);  y_max += margin * (y_max - y_min)

    gx = np.linspace(x_min, x_max, grid_n)
    gy = np.linspace(y_max, y_min, grid_n)
    GX, GY = np.meshgrid(gx, gy)
    grid_pts = np.column_stack([GX.ravel(), GY.ravel()])

    tree = cKDTree(emb)
    _, nn_idxs = tree.query(grid_pts, k=n_nn)   # (grid_n**2, n_nn)

    n_pts    = grid_n ** 2
    alphabet = list(string.ascii_lowercase)
    lbl_list = [(alphabet[k] if k < 26 else alphabet[k // 26 - 1] + alphabet[k % 26])
                for k in range(n_pts)]

    fig = plt.figure(figsize=(4, 4 + grid_n * 0.8), dpi=FIG_DPI)
    gs  = fig.add_gridspec(
        1 + grid_n, grid_n,
        height_ratios=[8] + [1] * grid_n,
        hspace=0.4, wspace=0.3,
        left=0.04, right=0.97, top=0.94, bottom=0.03,
    )

    # ── UMAP scatter ─────────────────────────────────────────────
    ax_umap = fig.add_subplot(gs[0, :])
    ax_umap.scatter(emb[:, 0], emb[:, 1],
                    color='C0', s=0.1, alpha=0.1, zorder=1, rasterized=True)

    for k in range(n_pts):
        centroid = emb[nn_idxs[k]].mean(axis=0)
        ax_umap.text(*centroid, lbl_list[k], fontsize=7, ha='center', va='center',
                     color='k', fontweight='bold', zorder=4)

    ax_umap.axis('off')
    ax_umap.set_title(title, fontsize=11)

    # ── PSTH sub-panels ──────────────────────────────────────────
    for k in range(n_pts):
        nns      = nn_idxs[k]
        avg_resp = all_resp_flat[nns].mean(axis=0)        # (n_features,)
        mean_day = day_labels[nns].mean()
        color_d  = plt.cm.viridis(mean_day / max(n_days - 1, 1))

        row = k // grid_n
        col = k  % grid_n
        ax_p = fig.add_subplot(gs[1 + row, col])

        ax_p.plot(avg_resp, color=color_d, lw=1.2)
        ax_p.set_ylim(vmin_resp, vmax_resp)
        ax_p.axhline(0, color='k', lw=0.4, alpha=0.2)
        # ax_p.axvline(stim_start + lag_param, color='k', lw=0.4, alpha=0.2)
        # ax_p.axvline(stim_end   + lag_param, color='k', lw=0.4, alpha=0.2)
        ax_p.axis('off')
        ax_p.set_title(f'{lbl_list[k]}  P{mean_day + AGE_OFFSET:.0f}',
                       fontsize=7, pad=2, color=color_d)

    plt.show()


if st_analysis:
    plot_umap_grid_responses_st(
        emb_umap_st, all_resp_flat, labels_st, n_days,
        title='UMAP – single-trial responses (ST grid)',
        n_nn=60, lag_param=lag_param,
    )
